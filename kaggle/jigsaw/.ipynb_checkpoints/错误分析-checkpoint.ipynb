# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

import time
import string
from collections import defaultdict, deque
from sklearn.model_selection import StratifiedKFold
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# input_dir=r"C:\Users\Lenovo\Desktop\stupidcode\kaggle\jigsaw\error_analyze"
# aug1_paths=os.path.join(input_dir,f"aug_1\\data_df_aug1")
aug1_paths="./cv_analyze/luke_ruddit_0.860.csv"

# %%
roberta_val=pd.read_csv("./cv_analyze/roberta_0.824.csv")
def generate_comments(data):
    more_toxic_text=data[["more_toxic","encode_more","more_value"]]
    less_toxic_text=data[["less_toxic","encode_less","less_value"]]
    more_toxic_text=more_toxic_text.rename(columns={"more_toxic":"text","encode_more":"encode_text","more_value":"toxic_value"})
    less_toxic_text=less_toxic_text.rename(columns={"less_toxic":"text","encode_less":"encode_text","less_value":"toxic_value"})
    
    comments=pd.concat([more_toxic_text,less_toxic_text],axis=0)
    comments=comments.drop_duplicates(subset=None,keep="first",inplace=False) 
    return comments
def encode_label(data_df):
     # 不同训练结果下的偏差，进行一些处理 主要是luke的偏差
    comments=generate_comments(roberta_val)
    comments.index=comments["text"]
    index_encode_dict=comments.to_dict()["encode_text"]
    del comments
    # 选择直接赋值 而不再根据文本匹配 因为经过翻译后的结果可能不匹配
    encode_less_luke=data_df.apply(lambda row:index_encode_dict[row["less_toxic"]],axis=1)
    encode_more_luke=data_df.apply(lambda row:index_encode_dict[row["more_toxic"]],axis=1)
    data_df["encode_less"]=encode_less_luke
    data_df["encode_more"]=encode_more_luke
    return data_df
def sort_by_roberta(data_df):
    data_df["new_index"]=data_df.merge(roberta_val[["encode_less","encode_more","worker","Unnamed: 0"]],
         on=["encode_less","encode_more","worker"],how="left")["Unnamed: 0"]
    data_df.index=data_df["new_index"]
    data_df.sort_index(inplace=True)
    return data_df
def luke_process(data_df):
    data_df=encode_label(data_df)
    data_df=data_df.rename(columns={"less_toxic_pred":"less_value","more_toxic_pred":"more_value"})
    data_df["pair_True"]=data_df["less_value"]<data_df["more_value"]

    data_df=sort_by_roberta(data_df)
    return data_df

data_df=pd.read_csv(aug1_paths)
data_df=luke_process(data_df)

# %%
comments_rank=pd.read_csv("./cv_analyze/bt_work.csv")
comments_rank=comments_rank[["text","score"]]

comments_rank.index=comments_rank.text
text2rank=comments_rank.to_dict()["score"]

data_df["less_value"]=data_df.apply(lambda row:text2rank[row["less_toxic"]],axis=1)
data_df["more_value"]=data_df.apply(lambda row:text2rank[row["more_toxic"]],axis=1)
data_df["pair_True"]=data_df.less_value<data_df.more_value

# %%
data_df.pair_True.mean()
# Out:
# 0.7966321243523317

# %%
# data_df=pd.read_csv(aug1_paths)
data_df["label_min"]=data_df.apply(lambda row:row["encode_less"] if row["encode_less"]<row["encode_more"] else row["encode_more"],axis=1)
data_df["label_max"]=data_df.apply(lambda row:row["encode_less"] if row["encode_less"]>row["encode_more"] else row["encode_more"],axis=1)
data_df["label_min_text"]=data_df.apply(lambda row:row["less_toxic"] if row["encode_less"]<row["encode_more"] else row["more_toxic"],axis=1)
data_df["label_max_text"]=data_df.apply(lambda row:row["less_toxic"] if row["encode_less"]>row["encode_more"] else row["more_toxic"],axis=1)
data_df["label_min_value"]=data_df.apply(lambda row:row["less_value"] if row["encode_less"]<row["encode_more"] else row["more_value"],axis=1)
data_df["label_max_value"]=data_df.apply(lambda row:row["less_value"] if row["encode_less"]>row["encode_more"] else row["more_value"],axis=1)

data_df["win_min"]=data_df.apply(lambda row:1 if row["label_min"]==row["encode_more"] else 0,axis=1)
data_df["win_max"]=data_df.apply(lambda row:0 if row["label_min"]==row["encode_more"] else 1,axis=1)

## pair True 已经失效

# data_df["pair_True"].replace({True:1,False:-1},inplace=True)

# %%
origin_data_df=data_df[data_df["worker"]!=999]
aug_data_df=data_df[data_df["worker"]==999]

print("origin_cv:",origin_data_df["pair_True"].mean())
print("aug_data_cv:",aug_data_df["pair_True"].mean())
# Out:
# origin_cv: 0.7966321243523317
# aug_data_cv: nan

# %%
origin_data_df_agg=origin_data_df.groupby(["label_min","label_max","label_min_value","label_max_value","label_min_text","label_max_text"]).agg({"win_min":"sum","win_max":"sum"}).reset_index()

# %%
origin_data_df_agg["pair_True"]=((origin_data_df_agg.label_min_value-origin_data_df_agg.label_max_value)*(
    origin_data_df_agg.win_min-origin_data_df_agg.win_max))>0

origin_data_df_agg.pair_True.mean()
# Out:
# 0.9207558369608231

# %%
# origin_error_df=origin_data_df[origin_data_df["pair_True"]==False]
# aug_error_df=aug_data_df[aug_data_df["pair_True"]==False]
# #找到所有的false 组合的情况（包括被判断正确的组合）
origin_error_df=origin_data_df_agg[origin_data_df_agg["pair_True"]==False]

origin_error_df["encode_less"]=origin_error_df.apply(lambda row:row["label_min"] 
                                             if row["win_min"]<row["win_max"] else row["label_max"],axis=1)
origin_error_df["encode_more"]=origin_error_df.apply(lambda row:row["label_min"] 
                                             if row["win_min"]>row["win_max"] else row["label_max"],axis=1)

# # 92%的错误都来自 毒性相似句子 所有句子对中 52%是毒性相似句子
confuse_error_df=origin_error_df[(origin_error_df["win_min"]!=0) & (origin_error_df["win_max"]!=0)]
len(confuse_error_df)/len(origin_error_df)
# Out:
# C:\Users\sleep\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\sleep\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# 0.978776529338327

# %%
origin_error_df
# Out:
#        label_min  label_max  label_min_value  label_max_value  \
# 7              4       5765             3533             3340
# 8              5       1351             3674             6948
# 14            10        478            10289             1080
# 20            12      11826             3767             4365
# 27            16       6316            10574            10120
# ...          ...        ...              ...              ...
# 10039      13059      13859            10241            13753
# 10040      13063      13727            10985            10425
# 10089      13679      13878              485             3685
# 10100      13817      14019            10197            10965
# 10104      13890      14095            10165            10759
#
#                                           label_min_text  \
# 7       \n\n koreans claim  \n\ni see youve seen the ...
# 8       \n\nFailure to follow the guidelines of WP:NO...
# 14      \n\nIm sorry but this guy is a real douchebag...
# 20      \n\nOh really??? 15% Huh? wow who knew that 1...
# 27      \n\nThat USAF dude is wearing a brown vest, n...
# ...                                                  ...
# 10039  Your Boy\n\nAppoloBoy is at it again. If your ...
# 10040  Your Ignorant Prejudice against the 10-string ...
# 10089              maybe 2 for each eye.  yup, 20 cocks.
# 10100  reference desk - oscillator\n\nSorry about my ...
# 10104  stop your lying. the jews of the biblical era ...
#
#                                           label_max_text  win_min  win_max  \
# 7      "\n\nWell, it appears that that vandal has res...        1        2
# 8       I'd rather he took the time to report me than...        2        1
# 14      Big Wang \nSometimes, I prefer to insert a ph...        1        2
# 20     Then Assert Your Case; Please Do...\n\nYou wri...        2        1
# 27     "\nI read that quality article, reference numb...        1        2
# ...                                                  ...      ...      ...
# 10039                         so block me, stupid prick!        2        1
# 10040  npov\nYou yell at me about NPOV, but your the ...        1        2
# 10089  starcraft 2 isnt even out yet. But hell, he's ...        2        1
# 10100  well terrilja , thats what u get , if you eras...        2        1
# 10104               yea soooo  ur stupidd!!!!!!!!! loser        2        1
#
#        pair_True  encode_less  encode_more
# 7          False            4         5765
# 8          False         1351            5
# 14         False           10          478
# 20         False        11826           12
# 27         False           16         6316
# ...          ...          ...          ...
# 10039      False        13859        13059
# 10040      False        13063        13727
# 10089      False        13878        13679
# 10100      False        14019        13817
# 10104      False        14095        13890
#
# [801 rows x 11 columns]

# %%
origin_data_df_agg.shape
# Out:
# (10108, 4)

# %%
origin_data_df_agg=origin_data_df.groupby(["label_min","label_max"]).agg({"win_min":"sum","win_max":"sum"}).reset_index()

# %%
confuse_df=origin_data_df_agg[(origin_data_df_agg["win_min"]!=0) & (origin_data_df_agg["win_max"]!=0)]

# %%
confuse_df
# Out:
#        label_min  label_max  win_min  win_max
# 0              0       7085        2        1
# 3              1      12696        2        1
# 4              2      13776        2        1
# 6              4       2804        1        2
# 7              4       5765        1        2
# ...          ...        ...      ...      ...
# 10099      13809      13932        2        1
# 10100      13817      14019        2        1
# 10102      13838      13944        1        2
# 10103      13881      14114        2        1
# 10104      13890      14095        2        1
#
# [5302 rows x 4 columns]

# %%
data_df_agg=data_df.groupby(["label_min","label_max"]).agg({"win_min":"sum","win_max":"sum"}).reset_index()


data_df_agg[(data_df_agg["win_min"]!=0) & (data_df_agg["win_max"]!=0)]
# Out:
#        label_min  label_max  win_min  win_max
# 0              0       7085        2        1
# 3              1      12696        2        1
# 4              2      13776        2        1
# 6              4       2804        1        2
# 7              4       5765        1        2
# ...          ...        ...      ...      ...
# 10099      13809      13932        2        1
# 10100      13817      14019        2        1
# 10102      13838      13944        1        2
# 10103      13881      14114        2        1
# 10104      13890      14095        2        1
#
# [5302 rows x 4 columns]

# %%
data_df.query("label_min==3 and label_max==3011")
# Out:
#            worker                                         less_toxic  \
# new_index
# 28035         404  \nU POUR ADMIN, U UPDATE VANDAL COUNT, WHILE R...
# 28036         410  \nU POUR ADMIN, U UPDATE VANDAL COUNT, WHILE R...
# 28037         560  \nU POUR ADMIN, U UPDATE VANDAL COUNT, WHILE R...
#
#                                                   more_toxic  encode_less  \
# new_index
# 28035       Your relentless edit warring \n\nYour message...            3
# 28036       Your relentless edit warring \n\nYour message...            3
# 28037       Your relentless edit warring \n\nYour message...            3
#
#            encode_more  group  fold  less_value  more_value  pair_True  \
# new_index
# 28035             3011   2740     4    0.541299    0.488886      False
# 28036             3011   2740     4    0.541299    0.488886      False
# 28037             3011   2740     4    0.541299    0.488886      False
#
#            new_index  label_min  label_max  \
# new_index
# 28035          28035          3       3011
# 28036          28036          3       3011
# 28037          28037          3       3011
#
#                                               label_min_text  \
# new_index
# 28035      \nU POUR ADMIN, U UPDATE VANDAL COUNT, WHILE R...
# 28036      \nU POUR ADMIN, U UPDATE VANDAL COUNT, WHILE R...
# 28037      \nU POUR ADMIN, U UPDATE VANDAL COUNT, WHILE R...
#
#                                               label_max_text  label_min_value  \
# new_index
# 28035       Your relentless edit warring \n\nYour message...         0.541299
# 28036       Your relentless edit warring \n\nYour message...         0.541299
# 28037       Your relentless edit warring \n\nYour message...         0.541299
#
#            label_max_value  win_min  win_max
# new_index
# 28035             0.488886        0        1
# 28036             0.488886        0        1
# 28037             0.488886        0        1

# %%
origin_error_df_agg
# Out:
#       label_min  label_max  win_min  win_max  encode_less  encode_more
# 0             0       7085        0        1            0         7085
# 1             1      12696        0        1            1        12696
# 2             2      13776        0        1            2        13776
# 3             3       3011        0        3            3         3011
# 4             4       2804        1        0         2804            4
# ...         ...        ...      ...      ...          ...          ...
# 5954      13809      13932        0        1        13809        13932
# 5955      13817      14019        0        1        13817        14019
# 5956      13838      13944        1        0        13944        13838
# 5957      13881      14114        0        1        13881        14114
# 5958      13890      14095        2        0        14095        13890
#
# [5959 rows x 6 columns]

# %%
origin_error_df=origin_data_df[origin_data_df["pair_True"]==False]

origin_true_df=origin_data_df[origin_data_df["pair_True"]==True]

# %%
fig,axs=plt.subplots(3,3,figsize=(20,10))
sns.kdeplot(data=origin_error_df["less_value"],ax=axs[0][0])
sns.kdeplot(data=origin_error_df["more_value"],ax=axs[1][0])
sns.kdeplot(data=origin_error_df["more_value"]-origin_error_df["less_value"],ax=axs[2][0])

sns.kdeplot(data=origin_data_df["less_value"],ax=axs[0][1])
sns.kdeplot(data=origin_data_df["more_value"],ax=axs[1][1])
sns.kdeplot(data=origin_data_df["more_value"]-origin_data_df["less_value"],ax=axs[2][1])

sns.kdeplot(data=origin_true_df["less_value"],ax=axs[0][2])
sns.kdeplot(data=origin_true_df["more_value"],ax=axs[1][2])
sns.kdeplot(data=origin_true_df["more_value"]-origin_true_df["less_value"],ax=axs[2][2])

# %%
origin_error_df.columns
# Out:
# Index(['worker', 'less_toxic', 'more_toxic', 'encode_less', 'encode_more',
#        'group', 'fold', 'less_value', 'more_value', 'pair_True', 'new_index',
#        'label_min', 'label_max', 'label_min_text', 'label_max_text',
#        'label_min_value', 'label_max_value', 'is_lost'],
#       dtype='object')

# %%
origin_error_df_agg=origin_error_df.groupby(["label_min","label_max"]).agg({"win_min":"sum","win_max":"sum"}).reset_index()
origin_error_df_agg["encode_less"]=origin_error_df_agg.apply(lambda row:row["label_min"] 
                                             if row["win_min"]<row["win_max"] else row["label_max"],axis=1)
origin_error_df_agg["encode_more"]=origin_error_df_agg.apply(lambda row:row["label_min"] 
                                             if row["win_min"]>row["win_max"] else row["label_max"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-35-5f048a22a9d1> in <module>
# ----> 1 origin_error_df_agg=origin_error_df.groupby(["label_min","label_max"]).agg({"win_min":"sum","win_max":"sum"}).reset_index()
#       2 origin_error_df_agg["encode_less"]=origin_error_df_agg.apply(lambda row:row["label_min"]
#       3                                              if row["win_min"]<row["win_max"] else row["label_max"],axis=1)
#       4 origin_error_df_agg["encode_more"]=origin_error_df_agg.apply(lambda row:row["label_min"]
#       5                                              if row["win_min"]>row["win_max"] else row["label_max"],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     938         func = _maybe_mangle_lambdas(func)
#     939
# --> 940         result, how = self._aggregate(func, *args, **kwargs)
#     941         if how is None:
#     942             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     364                     obj.columns.intersection(keys)
#     365                 ) != len(keys):
# --> 366                     raise SpecificationError("nested renamer is not supported")
#     367
#     368             from pandas.core.reshape.concat import concat
#
# SpecificationError: nested renamer is not supported

# %%
origin_data_df_agg=origin_data_df.groupby(["label_min","label_max","label_min_text","label_max_text"
                                        ]).agg({"win_min":"sum","win_max":"sum","label_min_value":"mean","label_max_value":"mean","pair_True":"mean"}).reset_index()
origin_data_df_agg["value_gap"]=origin_data_df_agg.apply(lambda row:row["label_max_value"]-row["label_min_value"] 
                                                         if row["win_max"]>row["win_min"] else row["label_min_value"]-row["label_max_value"],axis=1)
origin_data_df_agg["win_gap"]=origin_data_df_agg.apply(lambda row:(row["win_max"]-row["win_min"])/(row["win_max"]+row["win_min"])
                                                         if row["win_max"]>row["win_min"] else (row["win_min"]-row["win_max"])/(row["win_max"]+row["win_min"]),axis=1)
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-13-a48d1fcc37ad> in <module>
#       1 origin_data_df_agg=origin_data_df.groupby(["label_min","label_max","label_min_text","label_max_text"
# ----> 2                                         ]).agg({"win_min":"sum","win_max":"sum","label_min_value":"mean","label_max_value":"mean","pair_True":"mean"}).reset_index()
#       3 origin_data_df_agg["value_gap"]=origin_data_df_agg.apply(lambda row:row["label_max_value"]-row["label_min_value"]
#       4                                                          if row["win_max"]>row["win_min"] else row["label_min_value"]-row["label_max_value"],axis=1)
#       5 origin_data_df_agg["win_gap"]=origin_data_df_agg.apply(lambda row:(row["win_max"]-row["win_min"])/(row["win_max"]+row["win_min"])
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     938         func = _maybe_mangle_lambdas(func)
#     939
# --> 940         result, how = self._aggregate(func, *args, **kwargs)
#     941         if how is None:
#     942             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     364                     obj.columns.intersection(keys)
#     365                 ) != len(keys):
# --> 366                     raise SpecificationError("nested renamer is not supported")
#     367
#     368             from pandas.core.reshape.concat import concat
#
# SpecificationError: nested renamer is not supported

# %%
origin_data_df_agg.head()
# Out:
#    label_min  label_max                                     label_min_text  \
# 0          0       7085  \n\nThe comment directly above this one are fr...
# 1          1       1293  \n\nwhy should people have to read crap posted...
# 2          1       5156  \n\nwhy should people have to read crap posted...
# 3          1      12696  \n\nwhy should people have to read crap posted...
# 4          2      13776      \nGo F yourself you cottonheadednittymuggins.
#
#                                       label_max_text  win_min  win_max  \
# 0  "::you wouldn't know Makoto from Street Fighte...      2.0      1.0
# 1   I just read what you wrote; neither of the tw...      3.0      0.0
# 2  "\n\nI don't know which ""personal attacks"" y...      3.0      0.0
# 3  Yes it is. This is NOT an encyclopedia, it is ...      2.0      1.0
# 4  people like you are the reason wikipedia is us...      2.0      1.0
#
#    label_min_value  label_max_value  pair_True  value_gap   win_gap
# 0        -0.075334        -0.183623   0.666667   0.108288  0.333333
# 1         0.487768        -0.248887   1.000000   0.736656  1.000000
# 2         0.487768        -0.509758   1.000000   0.997527  1.000000
# 3         0.487768         0.208761   0.666667   0.279007  0.333333
# 4         0.813417        -0.380262   0.666667   1.193679  0.333333

# %%
#2291 条数据错误 7817条正确
origin_data_error=origin_data_df_agg[origin_data_df_agg["pair_True"]<0.5]
origin_data_true=origin_data_df_agg[origin_data_df_agg["pair_True"]>0.5]
len(origin_data_true)/len(origin_data_df_agg)
# Out:
# 0.8396319746735259

# %%
# origin_data_error.to_csv(os.path.join(input_dir,f"aug_1\\origin_data_error.csv"))
# origin_data_true.to_csv(os.path.join(input_dir,f"aug_1\\origin_data_true.csv"))

# %%
dict(origin_data_true["win_gap"].value_counts())[1/3]
# Out:
# 3905

# %%
#对正确的部分 划分为正1 正2 根据赢多少的比例来
win_gap_num=dict(origin_data_true["win_gap"].value_counts())
true_point=win_gap_num[1/3]/(win_gap_num[1/3]+win_gap_num[1])
true_val_gap=list(origin_data_true["value_gap"].sort_values())
true_point_value=true_val_gap[int(true_point*len(true_val_gap))]
origin_data_true["degree"]=origin_data_true.apply(lambda row:2 if row["value_gap"]>true_point_value else 1,axis=1)

origin_true_degree2=origin_data_true[origin_data_true["degree"]==2]
origin_true_degree1=origin_data_true[origin_data_true["degree"]==1]
# Out:
# D:\anaconda\envs\python36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#对错误的部分 也划分为 负1 和负2
false_gap_num=dict(origin_data_error["win_gap"].value_counts())
false_point=false_gap_num[1/3]/(false_gap_num[1/3]+false_gap_num[1])
false_val_gap=list(origin_data_error["value_gap"].sort_values())
false_point_value=false_val_gap[int(false_point*len(false_val_gap))]
origin_data_error["degree"]=origin_data_error.apply(lambda row:1 if row["value_gap"]>false_point_value else 2,axis=1)

origin_false_degree2=origin_data_error[origin_data_error["degree"]==2]
origin_false_degree1=origin_data_error[origin_data_error["degree"]==1]
# Out:
# D:\anaconda\envs\python36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # 绘图
